# %%
import pandas as pd

# %%
stanzadf = pd.read_csv(r'stanza_anotacia.csv', sep=';')

# %%
snkdf = pd.read_csv(r'SNK_anotacia.csv', sep=';')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
snkdf
# Out:
#              Slovo     Slovný druh      Rod     Číslo        Pád  \
# 0              Kde          Zámeno      NaN       NaN        NaN
# 1               tá          Zámeno   ženský  jednotné  nominatív
# 2           ľudská   Prídavné meno   ženský  jednotné  nominatív
# 3             duša  Podstatné meno   ženský  jednotné  nominatív
# 4           drieme         Sloveso      NaN  jednotné        NaN
# ...            ...             ...      ...       ...        ...
# 105692          na       Predložka      NaN       NaN        NaN
# 105693        Zemi  Podstatné meno   ženský  jednotné      lokál
# 105694       veľmi       Príslovka      NaN       NaN        NaN
# 105695  premenlivé   Prídavné meno  stredný  jednotné  nominatív
# 105696           .    Interpunkcia      NaN       NaN        NaN
#
#            Paradigma   Stupeň Aglutinovanosť Slovesná forma         Vid  \
# 0        príslovková      NaN            NaN            NaN         NaN
# ...

# %%
stanzadf
# Out:
#              Slovo     Slovný druh      Rod     Číslo        Pád  \
# 0              Kde          Zámeno      NaN       NaN        NaN
# 1               tá          Zámeno   ženský  jednotné  nominatív
# 2           ľudská   Prídavné meno   ženský  jednotné  nominatív
# 3             duša  Podstatné meno   ženský  jednotné  nominatív
# 4           drieme         Sloveso      NaN  jednotné        NaN
# ...            ...             ...      ...       ...        ...
# 106095          na       Predložka      NaN       NaN        NaN
# 106096        Zemi  Podstatné meno   ženský  jednotné      lokál
# 106097       veľmi       Príslovka      NaN       NaN        NaN
# 106098  premenlivé   Prídavné meno  stredný  jednotné  nominatív
# 106099           .    Interpunkcia      NaN       NaN        NaN
#
#            Paradigma   Stupeň  Aglutinovanosť Slovesná forma         Vid  \
# 0        príslovková      NaN             NaN            NaN         NaN
# ...

# %%
df = stanzadf

# %%
df = df.iloc[ : ,0:2]

# %%
df
# Out:
#              Slovo     Slovný druh
# 0              Kde          Zámeno
# 1               tá          Zámeno
# 2           ľudská   Prídavné meno
# 3             duša  Podstatné meno
# 4           drieme         Sloveso
# ...            ...             ...
# 106095          na       Predložka
# 106096        Zemi  Podstatné meno
# 106097       veľmi       Príslovka
# 106098  premenlivé   Prídavné meno
# 106099           .    Interpunkcia
#
# [106100 rows x 2 columns]

# %%
for i, slovo in df.iterrows:
    for j,slovo2 in snkdf.iterrows:
        if slovo == slovo2
        row = {}
        row['Slovo2'] = slovo2.Slovo
        row['Slovný druh'] = snkdf['Slovný druh'][j]
        break
    df = df.append(row, ignore_index = True)
